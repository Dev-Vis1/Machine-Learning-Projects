# %%
import numpy as np

# %%
mydata = np.loadtxt(fname="data0.txt")
mydata1 = np.loadtxt(fname="data1.txt")
mydata
# Out:
# array([[ 4.998, 13.025,  1.   ],
#        [ 5.948, 13.523,  1.   ],
#        [12.928, 18.   ,  1.   ],
#        [10.278, 17.089,  1.   ],
#        [ 9.845, 18.   ,  1.   ],
#        [ 6.754, 16.278,  1.   ],
#        [13.545, 18.   ,  1.   ],
#        [15.973, 18.   ,  1.   ],
#        [16.579, 18.   ,  1.   ],
#        [12.733, 18.   ,  1.   ],
#        [ 3.524, 13.978,  1.   ],
#        [ 2.744, 12.653,  1.   ],
#        [ 8.021, 14.281,  1.   ],
#        [ 9.74 , 18.   ,  1.   ],
#        [ 0.168, 14.285,  1.   ],
#        [16.811, 18.012,  1.   ],
#        [15.002, 17.822,  1.   ],
#        [16.24 , 18.1  ,  1.   ],
#        [17.18 , 17.901,  1.   ],
#        [ 4.497, 14.297,  1.   ],
#        [ 5.36 , 11.94 ,  0.   ],
#        [10.29 , 12.78 ,  0.   ],
#        [ 6.78 , 12.25 ,  0.   ],
#        [14.62 , 15.72 ,  0.   ],
#        [ 8.24 , 11.38 ,  0.   ],
#        [ 5.7  ,  7.3  ,  0.   ],
#        [ 2.74 ,  9.33 ,  0.   ],
#        [11.22 , 14.24 ,  0.   ],
#        [12.33 , 14.8  ,  0.   ],
#        [ 2.18 , 10.56 ,  0.   ],
#        [14.73 , 13.29 ,  0.   ],
#        [16.43 , 16.47 ,  0.   ],
#        [ 5.91 ,  7.59 ,  0.   ],
#        [ 3.32 ,  9.97 ,  0.   ],
#        [ 1.15 ,  6.64 ,  0.   ],
#        [ 2.77 , 11.72 ,  0.   ],
#        [12.94 , 10.2  ,  0.   ],
#        [16.31 , 13.72 ,  0.   ],
#        [ 6.73 , 11.48 ,  0.   ],
#        [15.58 , 13.85 ,  0.   ]])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(mydata[:,0],mydata[:,1],c=mydata[:,2])

# %%
class LinearClassifier:
    
    def __init__(self):
        print("Initializing")
        
    def train(self,Xtrain):
        print("TRaining")
        self.Xtrain =Xtrain
        Xvalues = np.linspace(0,18,20)
        plt.scatter(mydata[:,0],mydata[:,1],c=mydata[:,2])
        #Select only data 0
        X =self.Xtrain[np.where(self.Xtrain[:,2]==0),0][0]
        Y =self.Xtrain[np.where(self.Xtrain[:,2]==0),1][0]
        A = np.vstack([X, np.ones(len(X))]).T
        solu = np.linalg.lstsq(A,Y, rcond=None)
        m,b = solu[0]
        yhat = m * Xvalues + b
        plt.plot(Xvalues,yhat, c="purple")
        
         #Select only data 1
        X =self.Xtrain[np.where(self.Xtrain[:,2]==1),0][0]
        Y =self.Xtrain[np.where(self.Xtrain[:,2]==1),1][0]
        A = np.vstack([X, np.ones(len(X))]).T
        solu = np.linalg.lstsq(A,Y, rcond=None)
        my,by = solu[0]
        yhat = my * Xvalues + by
        plt.plot(Xvalues,yhat, c="yellow")
        
        
        #mean value
        self.mm = (m+my)/2
        self.bm = (b+by)/2
        self.yhat = mm * Xvalues + bm
        plt.plot(Xvalues,yhat, c ="black")
        
    def predict(self,Xtest):
        
        X =self.Xtest[0]
        Y =self.Xtest[1]
        yhat1 = self.mm * Xtest + self.bm
        
        if yhat1 > Y:
                      print("Test data is yellow")
        else:
                       print("Test data is purple")

# %%
classificator = LinearClassifier()
classificator.train(mydata)
classificator.predict([8.0,10.0])
# Out:
# Initializing
# TRaining
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32812\4126569048.py in <module>
#       1 classificator = LinearClassifier()
# ----> 2 classificator.train(mydata)
#       3 classificator.predict([8.0,10.0])
#
# ~\AppData\Local\Temp\ipykernel_32812\3282639075.py in train(self, Xtrain)
#      31         self.mm = (m+my)/2
#      32         self.bm = (b+by)/2
# ---> 33         self.yhat = mm * Xvalues + bm
#      34         plt.plot(Xvalues,yhat, c ="black")
#      35
#
# NameError: name 'mm' is not defined

# %%
classificator.train(mydata1)
# Out:
# TRaining
